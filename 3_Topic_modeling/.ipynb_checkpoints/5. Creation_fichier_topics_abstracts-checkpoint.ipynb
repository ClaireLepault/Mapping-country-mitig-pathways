# %%
import pandas as pd
import numpy as np
import joblib

# %%
(df, data_samples, tfidf, tfidf_feature_names) = joblib.load( "df-data_samples-tfidf-tfidf_names.pkl" )

# %% [markdown]
# Get the model that we generated earlier:

# %%
k_topics,alpha,l1,W,H = joblib.load("model_selected.pkl") 
param = [k_topics,alpha,l1,W,H]
param_names = ["k_topics", "alpha", "l1"]
for name in param_names:
    print(name, '=', repr(eval(name)))
# Out:
# k_topics = 38
# alpha = 0.14
# l1 = 0.1

# %% [markdown]
# ### Run the model

# %%
WH = W.dot(H)
WH.shape
# Out:
# (3813, 1262)

# %%
W.shape
# Out:
# (3813, 38)

# %%
liste = []
for n in range(len(H)):
    liste.append(np.sum(H[n,:]))
liste[0:10]
# Out:
# [15.1730907621389,
#  20.227097829889743,
#  13.301814321789639,
#  12.978146379613381,
#  15.724714185637081,
#  14.96553079870673,
#  44.754204124736916,
#  12.107770235531934,
#  17.82703621099995,
#  13.624605996787592]

# %% [markdown]
# ### Create matrix

# %%
matrix = np.zeros(W.shape)
for k in range(k_topics):
    topic_index = k
    sum_terms_topic = np.sum(H[topic_index,:])
    for n in range(len(df)):
        abstract_index = n
        sum_terms_abstract = np.sum(WH[abstract_index,:])
        abstract_topic = W[abstract_index,topic_index] * sum_terms_topic
        matrix[abstract_index,topic_index] = abstract_topic/sum_terms_abstract

# %%
matrix[:].round(2)
# Out:
# array([[0.12, 0.  , 0.11, ..., 0.  , 0.  , 0.04],
#        [0.05, 0.  , 0.  , ..., 0.  , 0.  , 0.  ],
#        [0.  , 0.18, 0.  , ..., 0.  , 0.06, 0.01],
#        ...,
#        [0.  , 0.07, 0.  , ..., 0.  , 0.01, 0.  ],
#        [0.  , 0.06, 0.  , ..., 0.  , 0.12, 0.08],
#        [0.  , 0.03, 0.  , ..., 0.  , 0.01, 0.  ]])

# %%
liste = []
for n in range(len(df)):
    liste.append(np.sum(matrix[n,:]))
liste[0:10]
# Out:
# [1.0,
#  1.0,
#  0.9999999999999999,
#  1.0,
#  1.0,
#  1.0,
#  0.9999999999999999,
#  0.9999999999999998,
#  0.9999999999999998,
#  1.0]

# %%
def get_5_words( all_terms, H, topic_index):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    top_terms=[]
    for i in range(5):
        term = tfidf_feature_names[top_indices[i]]
        top_terms.append(term)
    return top_terms

# %%
columns_topics = []
list_words_topics = []
for k in range(k_topics):
    words_topics = get_5_words(tfidf_feature_names, H , k)
    list_words_topics.append(words_topics)
    column_name = str(k) + '_'+ "_".join(words_topics)        
    columns_topics.append(column_name)

# %%
liste_rows = ["tot_pap","pap_wo_top","pap_w1top","pap_w2top","pap_w3top","pap_w4top","pap_w5top"] + columns_topics

# %%
def liste_seuils(pas,itera):
    #arrondir à la 2eme décimale
    seuil = round(0.05,2)
    seuils = [seuil]
    seuils_columns = ["seuil_"+ str(round(seuil,2))]
    for k in range(itera):
        seuil+= pas
        seuils.append(round(seuil,2))
        seuils_columns.append("seuil_"+ str(round(seuil,2)))
    return(seuils, seuils_columns)

# %%
liste_s = liste_seuils(0.01,10)

# %%
def prop_topics(matrix, columns_topics, liste_seuils, k_topics):
    seuils = liste_seuils[0]
    seuils_columns = liste_seuils[1]
    df = pd.DataFrame(columns= seuils_columns)
    df.columns.name = 'seuil'
    df['topic']= columns_topics
    df.set_index('topic', inplace = True)
    compteur_col = 0
    for seuil in seuils:
        column = seuils_columns[compteur_col] 
        compteur_col+=1
        b = (matrix>seuil).astype(int)
        df_binaire = pd.DataFrame(data = b)
        #Total sum per row: 
        df_binaire.loc['Total',:]= df_binaire.sum(axis=0)
        #Total sum per column: 
        df_binaire.loc[:,'Total'] = df_binaire.sum(axis=1)
        #How many topics characterize how many papers
        df_paper = pd.DataFrame(df_binaire.Total.value_counts(), columns=['Total'])
        print(df_paper.head(10))
        for i in range(k_topics):
            row = columns_topics[i]
            df.loc[row,[column]] = df_binaire.loc['Total',[i]].values[0]
    return(df, df_binaire)

# %%
prop = prop_topics(matrix, columns_topics, liste_s, k_topics)[0]
# Out:
#       Total
# 5.0     899
# 6.0     790
# 4.0     672
# 7.0     602
# 3.0     392
# 8.0     239
# 9.0     110
# 2.0      80
# 10.0     20
# 1.0       7
#          Total
# 5.0       1001
# 4.0        906
# 6.0        725
# 3.0        573
# 7.0        343
# 2.0        145
# 8.0         87
# 9.0         23
# 1.0          9
# 18311.0      1
#          Total
# 4.0       1115
# 5.0        943
# 3.0        826
# 6.0        501
# 2.0        242
# 7.0        140
# 1.0         22
# 8.0         22
# 9.0          2
# 16339.0      1
#          Total
# 4.0       1188
# 3.0       1146
# 5.0        775
# 2.0        364
# 6.0        250
# 1.0         48
# 7.0         41
# 14636.0      1
# 8.0          1
#          Total
# 3.0       1380
# 4.0       1170
# 2.0        569
# 5.0        514
# 6.0        100
# 1.0         73
# 7.0          7
# 13250.0      1
#          Total
# 3.0       1547
# 4.0        977
# 2.0        831
# 5.0        300
# 1.0        123
# 6.0         33
# 7.0          2
# 12046.0      1
#          Total
# 3.0       1598
# 2.0       1101
# 4.0        761
# 1.0        210
# 5.0        134
# 6.0          9
# 10974.0      1
#          Total
# 3.0       1504
# 2.0       1385
# 4.0        518
# 1.0        343
# 5.0         56
# 6.0          4
# 0.0          3
# 10001.0      1
#         Total
# 2.0      1615
# 3.0      1339
# 1.0       496
# 4.0       341
# 5.0        17
# 0.0         5
# 9192.0      1
#         Total
# 2.0      1834
# 3.0      1052
# 1.0       702
# 4.0       206
# 0.0        14
# 5.0         5
# 8375.0      1
#         Total
# 2.0      1899
# 1.0       929
# 3.0       839
# 4.0       103
# 0.0        39
# 5.0         4
# 7676.0      1

# %%
df_binaire = prop_topics(matrix, columns_topics, liste_s, k_topics)[1]

# %%
prop
# Out:
# seuil                                          seuil_0.05  seuil_0.06  \
# topic
# 0_energi_effici_consumpt_demand_secur                1155        1022
# 1_climat_chang_impact_global_adapt                   1135        1020
# 2_power_generat_plant_wind_capac                      590         526
# 3_vehicl_fleet_car_hybrid_passeng                     282         256
# 4_scenario_bau_altern_three_compar                    990         844
# 5_forest_sink_sequestr_wood_stock                     250         229
# 6_polici_develop_sustain_govern_countri              2038        1951
# 7_oil_product_crude_export_produc                     253         214
# 8_air_pollut_pm25_qualiti_health                      468         434
# 9_ccs_storag_captur_plant_geolog                      246         220
# 10_build_residenti_stock_hous_construct               282         239
# 11_transport_road_passeng_freight_mode                391         346
# 12_water_resourc_river_use_hydrolog                   216         190
# 13_coal_plant_coalfir_clean_util                      234         196
# 14_drought_precipit_extrem_frequenc_flood             105          96
# 15_industri_steel_product_iron_process                491         442
# 16_tax_revenu_polici_model_effect                     184         170
# 17_target_indc_achiev_level_nation                   1018         892
# 18_electr_generat_demand_system_suppli                737         654
# 19_agricultur_product_land_crop_food                  505         451
# 20_technolog_advanc_deploy_develop_lowcarbon          727         613
# 21_model_project_futur_region_temperatur             1726        1638
# 22_heat_pump_district_system_boiler                   221         187
# 23_nuclear_power_energi_plant_govern                  190         161
# 24_urban_citi_area_popul_develop                      309         269
# 25_hydrogen_cell_produc_chain_infrastructur            80          73
# 26_biomass_bioenergi_biofuel_residu_feedstock         274         240
# 27_renew_energi_solar_wind_sourc                      579         507
# 28_sector_model_residenti_power_bottomup              565         458
# 29_natur_consumpt_resourc_price_suppli                241         190
# 30_soil_deposit_organ_stock_sequestr                  235         203
# 31_wast_landfil_solid_ch4_methan                      287         247
# 32_cost_abat_option_econom_margin                     828         738
# 33_price_et_market_trade_polici                       517         454
# 34_cement_product_materi_substitut_effici              69          58
# 35_fuel_fossil_biofuel_diesel_altern                  498         400
# 36_peak_intens_structur_growth_econom                 821         726
# 37_million_ton_billion_consumpt_estim                 868         757
#
# seuil                                          seuil_0.07  seuil_0.08  \
# topic
# 0_energi_effici_consumpt_demand_secur                 885         760
# 1_climat_chang_impact_global_adapt                    911         823
# 2_power_generat_plant_wind_capac                      467         407
# 3_vehicl_fleet_car_hybrid_passeng                     240         228
# 4_scenario_bau_altern_three_compar                    718         600
# 5_forest_sink_sequestr_wood_stock                     212         204
# 6_polici_develop_sustain_govern_countri              1869        1776
# 7_oil_product_crude_export_produc                     181         166
# 8_air_pollut_pm25_qualiti_health                      394         374
# 9_ccs_storag_captur_plant_geolog                      195         185
# 10_build_residenti_stock_hous_construct               212         190
# 11_transport_road_passeng_freight_mode                307         265
# 12_water_resourc_river_use_hydrolog                   176         159
# 13_coal_plant_coalfir_clean_util                      159         141
# 14_drought_precipit_extrem_frequenc_flood              80          73
# 15_industri_steel_product_iron_process                384         341
# 16_tax_revenu_polici_model_effect                     154         135
# 17_target_indc_achiev_level_nation                    792         707
# 18_electr_generat_demand_system_suppli                589         522
# 19_agricultur_product_land_crop_food                  398         357
# 20_technolog_advanc_deploy_develop_lowcarbon          533         448
# 21_model_project_futur_region_temperatur             1533        1438
# 22_heat_pump_district_system_boiler                   162         143
# 23_nuclear_power_energi_plant_govern                  142         134
# 24_urban_citi_area_popul_develop                      241         225
# 25_hydrogen_cell_produc_chain_infrastructur            68          61
# 26_biomass_bioenergi_biofuel_residu_feedstock         214         193
# 27_renew_energi_solar_wind_sourc                      447         379
# 28_sector_model_residenti_power_bottomup              381         315
# 29_natur_consumpt_resourc_price_suppli                157         119
# 30_soil_deposit_organ_stock_sequestr                  186         175
# 31_wast_landfil_solid_ch4_methan                      210         188
# 32_cost_abat_option_econom_margin                     665         592
# 33_price_et_market_trade_polici                       397         355
# 34_cement_product_materi_substitut_effici              52          47
# 35_fuel_fossil_biofuel_diesel_altern                  328         282
# 36_peak_intens_structur_growth_econom                 644         546
# 37_million_ton_billion_consumpt_estim                 656         583
#
# seuil                                          seuil_0.09  seuil_0.1  \
# topic
# 0_energi_effici_consumpt_demand_secur                 681        595
# 1_climat_chang_impact_global_adapt                    742        679
# 2_power_generat_plant_wind_capac                      366        329
# 3_vehicl_fleet_car_hybrid_passeng                     219        207
# 4_scenario_bau_altern_three_compar                    524        444
# 5_forest_sink_sequestr_wood_stock                     199        187
# 6_polici_develop_sustain_govern_countri              1693       1614
# 7_oil_product_crude_export_produc                     141        128
# 8_air_pollut_pm25_qualiti_health                      345        319
# 9_ccs_storag_captur_plant_geolog                      168        159
# 10_build_residenti_stock_hous_construct               176        168
# 11_transport_road_passeng_freight_mode                244        221
# 12_water_resourc_river_use_hydrolog                   145        134
# 13_coal_plant_coalfir_clean_util                      127        109
# 14_drought_precipit_extrem_frequenc_flood              67         63
# 15_industri_steel_product_iron_process                307        271
# 16_tax_revenu_polici_model_effect                     130        123
# 17_target_indc_achiev_level_nation                    630        555
# 18_electr_generat_demand_system_suppli                462        411
# 19_agricultur_product_land_crop_food                  331        306
# 20_technolog_advanc_deploy_develop_lowcarbon          366        315
# 21_model_project_futur_region_temperatur             1354       1276
# 22_heat_pump_district_system_boiler                   125        114
# 23_nuclear_power_energi_plant_govern                  118        105
# 24_urban_citi_area_popul_develop                      206        189
# 25_hydrogen_cell_produc_chain_infrastructur            54         52
# 26_biomass_bioenergi_biofuel_residu_feedstock         180        166
# 27_renew_energi_solar_wind_sourc                      336        307
# 28_sector_model_residenti_power_bottomup              252        200
# 29_natur_consumpt_resourc_price_suppli                 99         85
# 30_soil_deposit_organ_stock_sequestr                  166        156
# 31_wast_landfil_solid_ch4_methan                      172        158
# 32_cost_abat_option_econom_margin                     518        479
# 33_price_et_market_trade_polici                       317        290
# 34_cement_product_materi_substitut_effici              45         42
# 35_fuel_fossil_biofuel_diesel_altern                  231        196
# 36_peak_intens_structur_growth_econom                 499        449
# 37_million_ton_billion_consumpt_estim                 515        445
#
# seuil                                          seuil_0.11  seuil_0.12  \
# topic
# 0_energi_effici_consumpt_demand_secur                 528         453
# 1_climat_chang_impact_global_adapt                    619         553
# 2_power_generat_plant_wind_capac                      303         272
# 3_vehicl_fleet_car_hybrid_passeng                     197         181
# 4_scenario_bau_altern_three_compar                    381         330
# 5_forest_sink_sequestr_wood_stock                     171         166
# 6_polici_develop_sustain_govern_countri              1556        1496
# 7_oil_product_crude_export_produc                     121         107
# 8_air_pollut_pm25_qualiti_health                      296         279
# 9_ccs_storag_captur_plant_geolog                      149         143
# 10_build_residenti_stock_hous_construct               162         156
# 11_transport_road_passeng_freight_mode                198         185
# 12_water_resourc_river_use_hydrolog                   124         112
# 13_coal_plant_coalfir_clean_util                       97          81
# 14_drought_precipit_extrem_frequenc_flood              58          51
# 15_industri_steel_product_iron_process                241         213
# 16_tax_revenu_polici_model_effect                     110         102
# 17_target_indc_achiev_level_nation                    492         448
# 18_electr_generat_demand_system_suppli                364         309
# 19_agricultur_product_land_crop_food                  283         263
# 20_technolog_advanc_deploy_develop_lowcarbon          280         245
# 21_model_project_futur_region_temperatur             1190        1134
# 22_heat_pump_district_system_boiler                   100          88
# 23_nuclear_power_energi_plant_govern                   92          87
# 24_urban_citi_area_popul_develop                      177         165
# 25_hydrogen_cell_produc_chain_infrastructur            47          46
# 26_biomass_bioenergi_biofuel_residu_feedstock         154         147
# 27_renew_energi_solar_wind_sourc                      278         242
# 28_sector_model_residenti_power_bottomup              164         131
# 29_natur_consumpt_resourc_price_suppli                 76          69
# 30_soil_deposit_organ_stock_sequestr                  146         135
# 31_wast_landfil_solid_ch4_methan                      139         124
# 32_cost_abat_option_econom_margin                     422         384
# 33_price_et_market_trade_polici                       264         232
# 34_cement_product_materi_substitut_effici              40          40
# 35_fuel_fossil_biofuel_diesel_altern                  159         131
# 36_peak_intens_structur_growth_econom                 403         362
# 37_million_ton_billion_consumpt_estim                 393         339
#
# seuil                                          seuil_0.13  seuil_0.14  \
# topic
# 0_energi_effici_consumpt_demand_secur                 387         326
# 1_climat_chang_impact_global_adapt                    507         462
# 2_power_generat_plant_wind_capac                      245         217
# 3_vehicl_fleet_car_hybrid_passeng                     170         164
# 4_scenario_bau_altern_three_compar                    286         246
# 5_forest_sink_sequestr_wood_stock                     163         155
# 6_polici_develop_sustain_govern_countri              1419        1325
# 7_oil_product_crude_export_produc                      96          87
# 8_air_pollut_pm25_qualiti_health                      262         244
# 9_ccs_storag_captur_plant_geolog                      135         131
# 10_build_residenti_stock_hous_construct               145         135
# 11_transport_road_passeng_freight_mode                172         156
# 12_water_resourc_river_use_hydrolog                   104          98
# 13_coal_plant_coalfir_clean_util                       70          65
# 14_drought_precipit_extrem_frequenc_flood              47          44
# 15_industri_steel_product_iron_process                201         187
# 16_tax_revenu_polici_model_effect                      96          87
# 17_target_indc_achiev_level_nation                    412         359
# 18_electr_generat_demand_system_suppli                279         247
# 19_agricultur_product_land_crop_food                  245         230
# 20_technolog_advanc_deploy_develop_lowcarbon          217         184
# 21_model_project_futur_region_temperatur             1060        1009
# 22_heat_pump_district_system_boiler                    81          75
# 23_nuclear_power_energi_plant_govern                   82          80
# 24_urban_citi_area_popul_develop                      153         143
# 25_hydrogen_cell_produc_chain_infrastructur            44          43
# 26_biomass_bioenergi_biofuel_residu_feedstock         135         125
# 27_renew_energi_solar_wind_sourc                      216         194
# 28_sector_model_residenti_power_bottomup              108          85
# 29_natur_consumpt_resourc_price_suppli                 62          57
# 30_soil_deposit_organ_stock_sequestr                  124         116
# 31_wast_landfil_solid_ch4_methan                      115         107
# 32_cost_abat_option_econom_margin                     345         306
# 33_price_et_market_trade_polici                       212         181
# 34_cement_product_materi_substitut_effici              39          37
# 35_fuel_fossil_biofuel_diesel_altern                  117          98
# 36_peak_intens_structur_growth_econom                 341         307
# 37_million_ton_billion_consumpt_estim                 300         263
#
# seuil                                          seuil_0.15
# topic
# 0_energi_effici_consumpt_demand_secur                 283
# 1_climat_chang_impact_global_adapt                    424
# 2_power_generat_plant_wind_capac                      196
# 3_vehicl_fleet_car_hybrid_passeng                     151
# 4_scenario_bau_altern_three_compar                    205
# 5_forest_sink_sequestr_wood_stock                     151
# 6_polici_develop_sustain_govern_countri              1264
# 7_oil_product_crude_export_produc                      75
# 8_air_pollut_pm25_qualiti_health                      227
# 9_ccs_storag_captur_plant_geolog                      124
# 10_build_residenti_stock_hous_construct               129
# 11_transport_road_passeng_freight_mode                134
# 12_water_resourc_river_use_hydrolog                    94
# 13_coal_plant_coalfir_clean_util                       61
# 14_drought_precipit_extrem_frequenc_flood              37
# 15_industri_steel_product_iron_process                171
# 16_tax_revenu_polici_model_effect                      78
# 17_target_indc_achiev_level_nation                    330
# 18_electr_generat_demand_system_suppli                212
# 19_agricultur_product_land_crop_food                  221
# 20_technolog_advanc_deploy_develop_lowcarbon          167
# 21_model_project_futur_region_temperatur              960
# 22_heat_pump_district_system_boiler                    65
# 23_nuclear_power_energi_plant_govern                   74
# 24_urban_citi_area_popul_develop                      131
# 25_hydrogen_cell_produc_chain_infrastructur            42
# 26_biomass_bioenergi_biofuel_residu_feedstock         113
# 27_renew_energi_solar_wind_sourc                      173
# 28_sector_model_residenti_power_bottomup               71
# 29_natur_consumpt_resourc_price_suppli                 50
# 30_soil_deposit_organ_stock_sequestr                  104
# 31_wast_landfil_solid_ch4_methan                       96
# 32_cost_abat_option_econom_margin                     264
# 33_price_et_market_trade_polici                       168
# 34_cement_product_materi_substitut_effici              36
# 35_fuel_fossil_biofuel_diesel_altern                   86
# 36_peak_intens_structur_growth_econom                 273
# 37_million_ton_billion_consumpt_estim                 236

# %%
df1 = prop.unstack(level=1)

# %%
df1.name = 'number_of_papers'
df2 = df1.fillna(0)
df2 = df2.reset_index()

# %% [markdown]
# import plotly.express as px
#
# fig = px.line(df2, x="seuil", y="number_of_papers", color='topic')
# fig.show()

# %%
number_of_abs = []
for i in range(k_topics):
    value = prop.iloc[:,0:1].values[i].copy()
    number_of_abs.append(value[0])

# %%
seuil1 = pd.DataFrame()
#seuil1.sort_values(by = ['number_of_abs'], ascending = [True], inplace = True)

# %%
seuil1['topics'] = columns_topics

# %%
seuil1['number_of_abstracts'] = number_of_abs

# %%
seuil1.sort_values(by = ['number_of_abstracts'], ascending =[True], inplace = True)

# %%
seuil1
# Out:
#                                            topics  number_of_abstracts
# 34      34_cement_product_materi_substitut_effici                   69
# 25    25_hydrogen_cell_produc_chain_infrastructur                   80
# 14      14_drought_precipit_extrem_frequenc_flood                  105
# 16              16_tax_revenu_polici_model_effect                  184
# 23           23_nuclear_power_energi_plant_govern                  190
# 12            12_water_resourc_river_use_hydrolog                  216
# 22            22_heat_pump_district_system_boiler                  221
# 13               13_coal_plant_coalfir_clean_util                  234
# 30           30_soil_deposit_organ_stock_sequestr                  235
# 29         29_natur_consumpt_resourc_price_suppli                  241
# 9                9_ccs_storag_captur_plant_geolog                  246
# 5               5_forest_sink_sequestr_wood_stock                  250
# 7               7_oil_product_crude_export_produc                  253
# 26  26_biomass_bioenergi_biofuel_residu_feedstock                  274
# 3               3_vehicl_fleet_car_hybrid_passeng                  282
# 10        10_build_residenti_stock_hous_construct                  282
# 31               31_wast_landfil_solid_ch4_methan                  287
# 24               24_urban_citi_area_popul_develop                  309
# 11         11_transport_road_passeng_freight_mode                  391
# 8                8_air_pollut_pm25_qualiti_health                  468
# 15         15_industri_steel_product_iron_process                  491
# 35           35_fuel_fossil_biofuel_diesel_altern                  498
# 19           19_agricultur_product_land_crop_food                  505
# 33                33_price_et_market_trade_polici                  517
# 28       28_sector_model_residenti_power_bottomup                  565
# 27               27_renew_energi_solar_wind_sourc                  579
# 2                2_power_generat_plant_wind_capac                  590
# 20   20_technolog_advanc_deploy_develop_lowcarbon                  727
# 18         18_electr_generat_demand_system_suppli                  737
# 36          36_peak_intens_structur_growth_econom                  821
# 32              32_cost_abat_option_econom_margin                  828
# 37          37_million_ton_billion_consumpt_estim                  868
# 4              4_scenario_bau_altern_three_compar                  990
# 17             17_target_indc_achiev_level_nation                 1018
# 1              1_climat_chang_impact_global_adapt                 1135
# 0           0_energi_effici_consumpt_demand_secur                 1155
# 21       21_model_project_futur_region_temperatur                 1726
# 6         6_polici_develop_sustain_govern_countri                 2038

# %%
def get_top_abstracts( data_samples, W, topic_index, n_top_abstracts ):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( W[:,topic_index] )[::-1]
    # now get the abstracts corresponding to the top-ranked indices
    top_abstracts = []
    for doc_index in top_indices[0:n_top_abstracts]:
        top_abstracts.append( data_samples[doc_index] )
    return top_abstracts

# %%
df['stem_abstract'] = pd.Series(data_samples)
df['topic_charact'] = np.nan
df_top_topic_abs = pd.DataFrame()

for k in range(k_topics):
    top_topic_abstracts = get_top_abstracts( data_samples, W, k, number_of_abs[k] )
    for i, abstract in enumerate(top_topic_abstracts):
        df_tempo = df[df['stem_abstract'].isin([str(abstract)])].copy()
        df_tempo['topic_charact'] = columns_topics[k]
        df_tempo['number_of_abs'] = number_of_abs[k]
        df_top_topic_abs = df_top_topic_abs.append(df_tempo)

# %%
df_top_topic_abs.reset_index(0,inplace = True)        
df_top_topic_abs['index1'] = df_top_topic_abs.index
col = ['index1','topic_charact','number_of_abs','title','abstract']
df_top_topic_abs = df_top_topic_abs.reindex(columns=col)

# %%
df_top_topic_abs.sort_values(by = ['number_of_abs','index1'], ascending = [True,True], inplace = True)

# %%
joblib.dump((df_top_topic_abs, list_words_topics,columns_topics), "dfseuil005_wordslist_columnstopics.pkl")
# Out:
# /home/cired/.local/lib/python3.5/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['dfseuil005_wordslist_columnstopics.pkl']
